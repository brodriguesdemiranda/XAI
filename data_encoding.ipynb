# %% [markdown]
# # Data Encoding

# %% [markdown]
# ## Importing the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/german_credit_data.csv")

# %%
df
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# 0             1169         6             radio/TV  good
# 1             5951        48             radio/TV   bad
# 2             2096        12            education  good
# 3             7882        42  furniture/equipment  good
# 4             4870        24                  car   bad
# ..             ...       ...                  ...   ...
# 995           1736        12  furniture/equipment  good
# 996           3857        30                  car  good
# 997            804        12             radio/TV  good
# 998           1845        45             radio/TV   bad
# 999           4576        45                  car  good
#
# [1000 rows x 11 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The first column of this dataframe is a copy of the index. This is already included in the dataframe, so we can remove it:

# %%
df = df.drop(columns = ['Unnamed: 0'], axis = 1)

# %% [markdown]
# What is the percentage of missing values in the data?

# %%
df.isnull().mean() * 100
# Out:
# Age                  0.0
# Sex                  0.0
# Job                  0.0
# Housing              0.0
# Saving accounts     18.3
# Checking account    39.4
# Credit amount        0.0
# Duration             0.0
# Purpose              0.0
# Risk                 0.0
# dtype: float64

# %% [markdown]
# Given the high percentage of missing values for _Checking Account_, we remove it:

# %%
df = df.drop(columns = ['Checking account'], axis = 1)

# %% [markdown]
# Filling missing values with a global constant:

# %%
df['Saving accounts'] = df['Saving accounts'].fillna('Missing')
# df['Checking account'] = df['Checking account'].fillna('Missing')

# %% [markdown]
# The feature 'sex' only has 2 values. Which value should be considered base case when binary encoding is used?

# %%
total = df.shape[0]

male_count = df["Sex"].value_counts()[0]
female_count = df["Sex"].value_counts()[1]

print(str(100 * male_count/total) +  "% of instances describe males while " + str(100 * female_count/total) + "% of instances describe females.")
# Out:
# 69.0% of instances describe males while 31.0% of instances describe females.

# %% [markdown]
# Male will be the base case, as females are less common.

# %% [markdown]
# Using One-Hot-Encoding:

# %%
tempDf = pd.get_dummies(df.drop(columns= ['Risk'],axis=1), drop_first=False)
tempDf['Risk'] = df['Risk']

df = tempDf

# %% [markdown]
# Considering males as base case, encoding females = 1:

# %%
df = df.drop(columns = ['Sex_male'], axis = 1)

# %% [markdown]
# Encoding our target variable:

# %%
df['Risk'] = df['Risk'].replace('bad', True)
df['Risk'] = df['Risk'].replace('good', False)

# %%
df
# Out:
#      Age  Job  Credit amount  Duration  Sex_female  Housing_free  Housing_own  \
# 0     67    2           1169         6           0             0            1
# 1     22    2           5951        48           1             0            1
# 2     49    1           2096        12           0             0            1
# 3     45    2           7882        42           0             1            0
# 4     53    2           4870        24           0             1            0
# ..   ...  ...            ...       ...         ...           ...          ...
# 995   31    1           1736        12           1             0            1
# 996   40    3           3857        30           0             0            1
# 997   38    2            804        12           0             0            1
# 998   23    2           1845        45           0             1            0
# 999   27    2           4576        45           0             0            1
#
#      Housing_rent  Saving accounts_Missing  Saving accounts_little  ...  \
# 0               0                        1                       0  ...
# 1               0                        0                       1  ...
# 2               0                        0                       1  ...
# 3               0                        0                       1  ...
# 4               0                        0                       1  ...
# ..            ...                      ...                     ...  ...
# 995             0                        0                       1  ...
# 996             0                        0                       1  ...
# 997             0                        0                       1  ...
# 998             0                        0                       1  ...
# 999             0                        0                       0  ...
#
#      Saving accounts_rich  Purpose_business  Purpose_car  \
# 0                       0                 0            0
# 1                       0                 0            0
# 2                       0                 0            0
# 3                       0                 0            0
# 4                       0                 0            1
# ..                    ...               ...          ...
# 995                     0                 0            0
# 996                     0                 0            1
# 997                     0                 0            0
# 998                     0                 0            0
# 999                     0                 0            1
#
#      Purpose_domestic appliances  Purpose_education  \
# 0                              0                  0
# 1                              0                  0
# 2                              0                  1
# 3                              0                  0
# 4                              0                  0
# ..                           ...                ...
# 995                            0                  0
# 996                            0                  0
# 997                            0                  0
# 998                            0                  0
# 999                            0                  0
#
#      Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                              0                 1                0
# 1                              0                 1                0
# 2                              0                 0                0
# 3                              1                 0                0
# 4                              0                 0                0
# ..                           ...               ...              ...
# 995                            1                 0                0
# 996                            0                 0                0
# 997                            0                 1                0
# 998                            0                 1                0
# 999                            0                 0                0
#
#      Purpose_vacation/others   Risk
# 0                          0  False
# 1                          0   True
# 2                          0  False
# 3                          0  False
# 4                          0   True
# ..                       ...    ...
# 995                        0  False
# 996                        0  False
# 997                        0  False
# 998                        0   True
# 999                        0  False
#
# [1000 rows x 22 columns]

# %% [markdown]
# # Exporting our data

# %% [markdown]
# ## Exporting general data

# %%
df.to_csv('data/encoded_dataset.csv', index = False)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2, random_state = 0)

# %%
train.to_csv('data/train.csv', index = False)
test.to_csv('data/test.csv', index = False)

# %% [markdown]
# This train/test set fold was used to find the model with the best score on the dataset.

# %% [markdown]
# ## Oversampling our training data

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=0)

# %%
outputVar = 'Risk'

X_train = train.drop(columns= [outputVar],axis=1)
y_train = train[outputVar]

# %%
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %%
resampled = X_resampled.copy()
resampled['Risk'] = y_resampled

resampled
# Out:
#       Age  Job  Credit amount  Duration  Sex_female  Housing_free  \
# 0      30    2           2862        36           0             1
# 1      27    2           3123        24           1             0
# 2      24    3           7408        60           1             0
# 3      25    2           1264        15           0             0
# 4      24    2           1554         6           1             0
# ...   ...  ...            ...       ...         ...           ...
# 1111   35    2            691        12           0             0
# 1112   46    2           3931        48           0             1
# 1113   43    2           4057        24           0             0
# 1114   44    3          12579        24           1             1
# 1115   34    3           1501         9           1             0
#
#       Housing_own  Housing_rent  Saving accounts_Missing  \
# 0               0             0                        0
# 1               1             0                        0
# 2               1             0                        0
# 3               0             1                        0
# 4               0             1                        0
# ...           ...           ...                      ...
# 1111            1             0                        0
# 1112            0             0                        0
# 1113            1             0                        0
# 1114            0             0                        0
# 1115            1             0                        0
#
#       Saving accounts_little  ...  Saving accounts_rich  Purpose_business  \
# 0                          0  ...                     0                 0
# 1                          1  ...                     0                 0
# 2                          0  ...                     0                 0
# 3                          0  ...                     0                 0
# 4                          1  ...                     0                 0
# ...                      ...  ...                   ...               ...
# 1111                       1  ...                     0                 0
# 1112                       1  ...                     0                 0
# 1113                       1  ...                     0                 0
# 1114                       1  ...                     0                 0
# 1115                       1  ...                     0                 0
#
#       Purpose_car  Purpose_domestic appliances  Purpose_education  \
# 0               1                            0                  0
# 1               1                            0                  0
# 2               1                            0                  0
# 3               1                            0                  0
# 4               0                            0                  0
# ...           ...                          ...                ...
# 1111            1                            0                  0
# 1112            1                            0                  0
# 1113            0                            0                  0
# 1114            1                            0                  0
# 1115            0                            0                  1
#
#       Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                               0                 0                0
# 1                               0                 0                0
# 2                               0                 0                0
# 3                               0                 0                0
# 4                               0                 1                0
# ...                           ...               ...              ...
# 1111                            0                 0                0
# 1112                            0                 0                0
# 1113                            1                 0                0
# 1114                            0                 0                0
# 1115                            0                 0                0
#
#       Purpose_vacation/others   Risk
# 0                           0  False
# 1                           0   True
# 2                           0   True
# 3                           0   True
# 4                           0  False
# ...                       ...    ...
# 1111                        0   True
# 1112                        0   True
# 1113                        0   True
# 1114                        0   True
# 1115                        0   True
#
# [1116 rows x 22 columns]

# %%
train['Risk'].value_counts()
# Out:
# False    558
# True     242
# Name: Risk, dtype: int64

# %%
resampled['Risk'].value_counts()
# Out:
# False    558
# True     558
# Name: Risk, dtype: int64

# %%
resampled.to_csv('data/resampled.csv', index = False)

# %% [markdown]
# ## Sampling our Data using SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state = 0)

# %%
X_smote, y_smote = smote.fit_resample(X_train, y_train)

# %%
dfSmote = X_resampled.copy()
dfSmote['Risk'] = y_resampled

dfSmote
# Out:
#       Age  Job  Credit amount  Duration  Sex_female  Housing_free  \
# 0      30    2           2862        36           0             1
# 1      27    2           3123        24           1             0
# 2      24    3           7408        60           1             0
# 3      25    2           1264        15           0             0
# 4      24    2           1554         6           1             0
# ...   ...  ...            ...       ...         ...           ...
# 1111   35    2            691        12           0             0
# 1112   46    2           3931        48           0             1
# 1113   43    2           4057        24           0             0
# 1114   44    3          12579        24           1             1
# 1115   34    3           1501         9           1             0
#
#       Housing_own  Housing_rent  Saving accounts_Missing  \
# 0               0             0                        0
# 1               1             0                        0
# 2               1             0                        0
# 3               0             1                        0
# 4               0             1                        0
# ...           ...           ...                      ...
# 1111            1             0                        0
# 1112            0             0                        0
# 1113            1             0                        0
# 1114            0             0                        0
# 1115            1             0                        0
#
#       Saving accounts_little  ...  Saving accounts_rich  Purpose_business  \
# 0                          0  ...                     0                 0
# 1                          1  ...                     0                 0
# 2                          0  ...                     0                 0
# 3                          0  ...                     0                 0
# 4                          1  ...                     0                 0
# ...                      ...  ...                   ...               ...
# 1111                       1  ...                     0                 0
# 1112                       1  ...                     0                 0
# 1113                       1  ...                     0                 0
# 1114                       1  ...                     0                 0
# 1115                       1  ...                     0                 0
#
#       Purpose_car  Purpose_domestic appliances  Purpose_education  \
# 0               1                            0                  0
# 1               1                            0                  0
# 2               1                            0                  0
# 3               1                            0                  0
# 4               0                            0                  0
# ...           ...                          ...                ...
# 1111            1                            0                  0
# 1112            1                            0                  0
# 1113            0                            0                  0
# 1114            1                            0                  0
# 1115            0                            0                  1
#
#       Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                               0                 0                0
# 1                               0                 0                0
# 2                               0                 0                0
# 3                               0                 0                0
# 4                               0                 1                0
# ...                           ...               ...              ...
# 1111                            0                 0                0
# 1112                            0                 0                0
# 1113                            1                 0                0
# 1114                            0                 0                0
# 1115                            0                 0                0
#
#       Purpose_vacation/others   Risk
# 0                           0  False
# 1                           0   True
# 2                           0   True
# 3                           0   True
# 4                           0  False
# ...                       ...    ...
# 1111                        0   True
# 1112                        0   True
# 1113                        0   True
# 1114                        0   True
# 1115                        0   True
#
# [1116 rows x 22 columns]

# %%
dfSmote['Risk'].value_counts()
# Out:
# False    558
# True     558
# Name: Risk, dtype: int64

# %%
dfSmote.to_csv('data/SMOTE.csv', index = False)
